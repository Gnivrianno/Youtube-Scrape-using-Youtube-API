# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyBjo2Lu5Qxm9eAT4162qZHXpEGjU62yPJI'
channel_usrname = 'Fireship'
channel_id = 'UCsBjURrPoezykLs9EqgamOA'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_id):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id
        )
    response = request.execute()

    allvideos_playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

                
    return allvideos_playlist_id

# %%
playlist_id = get_channel_stats(youtube, channel_id)

# %%
def get_video_ids(youtube, playlist_id):

    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id
        # id=','.join(playlist_id)
        # uncomment for multiple playlist_id
    )
    response = request.execute()

 
    video_id = response['items'][0]['contentDetails']['videoId'],
    

    return video_id

# %%
recent_video_id = get_video_ids(youtube, playlist_id)

# %%
def get_comments(youtube, video_id):

    all_data=[]

    request = youtube.commentThreads().list(
        part="snippet,replies",
        maxResults=100,
        videoId=video_id
    )

    response = request.execute()


    for i in range(len(response['items'])):
        is_replied = response['items'][i]['snippet']['totalReplyCount']
        if is_replied is None or is_replied == 0 :
            data = dict(username = response['items'][i]['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                    comments = response['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'],
                    user_channelid = response['items'][i]['snippet']['topLevelComment']['snippet']['authorChannelId']['value'],
                    posted_at = response['items'][i]['snippet']['topLevelComment']['snippet']['publishedAt'],
                    updated_at = response['items'][i]['snippet']['topLevelComment']['snippet']['updatedAt'],
                    likes = response['items'][i]['snippet']['topLevelComment']['snippet']['likeCount'],
                    replies = response['items'][i]['snippet']['totalReplyCount'],
                    reply = None

                    )
            all_data.append(data)

            
        
        else :
            try:
                for e in range(len(response['items'][i]['replies']['comments'])):
                    data = dict(username = response['items'][i]['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                            comments = response['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'],
                            user_channelid = response['items'][i]['snippet']['topLevelComment']['snippet']['authorChannelId']['value'],
                            posted_at = response['items'][i]['snippet']['topLevelComment']['snippet']['publishedAt'],
                            updated_at = response['items'][i]['snippet']['topLevelComment']['snippet']['updatedAt'],
                            likes = response['items'][i]['snippet']['topLevelComment']['snippet']['likeCount'],
                            replies = response['items'][i]['snippet']['totalReplyCount'],
                            reply = response['items'][i]['replies']['comments'][e]['snippet']['textDisplay']

                            )
                    all_data.append(data)

            except Exception :
                pass
            
                data = dict(username = response['items'][i]['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        comments = response['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'],
                        user_channelid = response['items'][i]['snippet']['topLevelComment']['snippet']['authorChannelId']['value'],
                        posted_at = response['items'][i]['snippet']['topLevelComment']['snippet']['publishedAt'],
                        updated_at = response['items'][i]['snippet']['topLevelComment']['snippet']['updatedAt'],
                        likes = response['items'][i]['snippet']['topLevelComment']['snippet']['likeCount'],
                        replies = response['items'][i]['snippet']['totalReplyCount'],
                        reply = None

                        )
                all_data.append(data)


    next_page_token = response.get('nextPageToken')
    more_pages = True

    while more_pages:
        if next_page_token is None:
            more_pages = False

        else :

                request = youtube.commentThreads().list(
                    part="snippet,replies",
                    maxResults=100,
                    pageToken = next_page_token,
                    videoId=video_id
                )

                response = request.execute()



                for i in range(len(response['items'])):
                    is_replied = response['items'][i]['snippet']['totalReplyCount']
                    if is_replied is None or is_replied == 0 :
                        data = dict(username = response['items'][i]['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                comments = response['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'],
                                user_channelid = response['items'][i]['snippet']['topLevelComment']['snippet']['authorChannelId']['value'],
                                posted_at = response['items'][i]['snippet']['topLevelComment']['snippet']['publishedAt'],
                                updated_at = response['items'][i]['snippet']['topLevelComment']['snippet']['updatedAt'],
                                likes = response['items'][i]['snippet']['topLevelComment']['snippet']['likeCount'],
                                replies = response['items'][i]['snippet']['totalReplyCount'],
                                reply = None

                                )
                        all_data.append(data)

                        
                    
                    else :
                        try:
                            for e in range(len(response['items'][i]['replies']['comments'])):
                                data = dict(username = response['items'][i]['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                        comments = response['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'],
                                        user_channelid = response['items'][i]['snippet']['topLevelComment']['snippet']['authorChannelId']['value'],
                                        posted_at = response['items'][i]['snippet']['topLevelComment']['snippet']['publishedAt'],
                                        updated_at = response['items'][i]['snippet']['topLevelComment']['snippet']['updatedAt'],
                                        likes = response['items'][i]['snippet']['topLevelComment']['snippet']['likeCount'],
                                        replies = response['items'][i]['snippet']['totalReplyCount'],
                                        reply = response['items'][i]['replies']['comments'][e]['snippet']['textDisplay']

                                        )
                                all_data.append(data)

                        except Exception :
                            pass
                        
                            data = dict(username = response['items'][i]['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                    comments = response['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'],
                                    user_channelid = response['items'][i]['snippet']['topLevelComment']['snippet']['authorChannelId']['value'],
                                    posted_at = response['items'][i]['snippet']['topLevelComment']['snippet']['publishedAt'],
                                    updated_at = response['items'][i]['snippet']['topLevelComment']['snippet']['updatedAt'],
                                    likes = response['items'][i]['snippet']['topLevelComment']['snippet']['likeCount'],
                                    replies = response['items'][i]['snippet']['totalReplyCount'],
                                    reply = None

                                    )
                            all_data.append(data)
                        

                next_page_token = response.get('nextPageToken')




            


    return all_data

# %%
all_data_comments = pd.DataFrame(get_comments(youtube, video_id))

# %%
all_data_comments.to_csv('All_comments_list.csv')
